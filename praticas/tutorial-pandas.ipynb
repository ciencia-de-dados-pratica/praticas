# %% [markdown]
# ### Introdução ao Pandas

# %% [markdown]
# Neste tutorial, iremos introduzir uma biblioteca muito útil para manipulação de conjunto de dados que se chama Pandas. O Pandas é uma biblioteca de código aberto que fornece estrutura de dados de alto desempenho e fácil de usar e ferramentas de análise de dados para a linguagem de programação Python.

# %% [markdown]
# Usaremos como fonte de dados o repositório da UCI. A UCI Machine Learning Repository é uma coleção de bancos de dados, teorias de domínio e geradores de dados que são utilizados pela comunidade de aprendizagem de máquina para a análise empírica de algoritmos de aprendizado de máquina. Tem sido amplamente utilizado por estudantes, educadores e pesquisadores de todo o mundo como fonte primária de conjuntos de dados de aprendizagem de máquina. Este projeto é em colaboração com a Rexa.info na Universidade de Massachusetts Amherst.
# Disponível em: https://archive.ics.uci.edu/ml/about.html

# %% [markdown]
# O repositório da UCI está disponível em: https://archive.ics.uci.edu/ml/index.php

# %% [markdown]
# Sem mais delongas, começaremos a importar o pandas.

# %%
# %matplotlib inline
import pandas as pd

# %% [markdown]
# Antes de manipularmos o dataset Isis, introduziremos dois conceitos muito importantes do Pandas que é o de séries e dataframes.

# %% [markdown]
# #### Séries

# %% [markdown]
# É uma matriz rotulada unidimensional capaz de manter qualquer tipo de dados (inteiros, strings, números de ponto flutuante, objetos Python, etc.). Os rótulos dos eixos são designados coletivamente como o índice.

# %%
# Criação de um vetor
v = [1,2,3,4,7,8,9,10,11,12]

# %%
v
# Out:
# [1, 2, 3, 4, 7, 8, 9, 10, 11, 12]

# %%
# Conversão do vetor v para uma Série serie.

serie = pd.Series(v)

# %%
serie
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 4     7
# 5     8
# 6     9
# 7    10
# 8    11
# 9    12
# dtype: int64

# %% [markdown]
# Note que após a conversão, o modo com que os dados são mostrados mudam tendo pra cada valor um índice associado. Isso acontece com o vetor v criado anteriormente mas de forma implicita. Este não é o único diferencial de séries, caso contrário não haveria sentido de usá-la. Este tipo de objeto possui uma gama de funções que facilitam a manipulação dos dados que veremos ao longo deste tutorial.

# %%
# Verifica se o conjunto de dados está vazio
serie.empty
# Out:
# False

# %%
# Mostra as dimensões do nosso conjundo de dados
serie.shape
# Out:
# (10,)

# %%
# Retorna seu tamanho
serie.size
# Out:
# 10

# %%
serie.values
# Out:
# array([ 1,  2,  3,  4,  7,  8,  9, 10, 11, 12])

# %%
serie.head(3)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
serie.tail(3)
# Out:
# 7    10
# 8    11
# 9    12
# dtype: int64

# %%
dicionario = serie.to_dict()

# %%
dicionario
# Out:
# {0: 1, 1: 2, 2: 3, 3: 4, 4: 7, 5: 8, 6: 9, 7: 10, 8: 11, 9: 12}

# %%
rotulos = list('abcdefghij')

serie2 = pd.Series(v, rotulos)

serie2
# Out:
# a     1
# b     2
# c     3
# d     4
# e     7
# f     8
# g     9
# h    10
# i    11
# j    12
# dtype: int64

# %%
serie2['a']
# Out:
# 1

# %% [markdown]
# #### DataFrames

# %% [markdown]
# DataFrame é uma estrutura de dados rotada bidimensional com colunas de tipos potencialmente diferentes. Você pode pensar nisso como uma planilha eletrônica ou tabela SQL, ou um ditador de objetos da série. É geralmente o objeto de pandas mais comumente usado. Como Series, o DataFrame aceita muitos tipos diferentes de entrada.

# %%
datas = pd.date_range('20180618',periods = 5)

# %%
datas
# Out:
# DatetimeIndex(['2018-06-18', '2018-06-19', '2018-06-20', '2018-06-21',
#                '2018-06-22'],
#               dtype='datetime64[ns]', freq='D')

# %%
colunas = ['a','b','c','d','e']

m = [[1 ,2 ,3   ,4  ,5 ],
     [2 ,3 ,43  ,45 ,1 ],
     [4 ,3 ,56  ,7  ,4 ],
     [8 ,6 ,4   ,32 ,2 ],
     [3 ,5 ,323 ,5  ,6]]
dataFrame = pd.DataFrame(m, index =datas , columns=colunas)

# %%
dataFrame
# Out:
#             a  b    c   d  e
# 2018-06-18  1  2    3   4  5
# 2018-06-19  2  3   43  45  1
# 2018-06-20  4  3   56   7  4
# 2018-06-21  8  6    4  32  2
# 2018-06-22  3  5  323   5  6

# %%
dataFrame['a']
# Out:
# 2018-06-18    1
# 2018-06-19    2
# 2018-06-20    4
# 2018-06-21    8
# 2018-06-22    3
# Freq: D, Name: a, dtype: int64

# %%
dataFrame['f'] = [1,2,3,4,5]
dataFrame
# Out:
#             a  b    c   d  e  f
# 2018-06-18  1  2    3   4  5  1
# 2018-06-19  2  3   43  45  1  2
# 2018-06-20  4  3   56   7  4  3
# 2018-06-21  8  6    4  32  2  4
# 2018-06-22  3  5  323   5  6  5

# %%
dataFrame.transpose()
# Out:
#    2018-06-18  2018-06-19  2018-06-20  2018-06-21  2018-06-22
# a           1           2           4           8           3
# b           2           3           3           6           5
# c           3          43          56           4         323
# d           4          45           7          32           5
# e           5           1           4           2           6
# f           1           2           3           4           5

# %%
dataFrame.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# d    int64
# e    int64
# f    int64
# dtype: object

# %% [markdown]
# #### Usando o  dataset Isis

# %% [markdown]
# O dataset que usaremos está disponível em: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data. Este dataset possui informações sobre um tipo de flor iris, cujo tipo pode ser setosa, versicolor ou virginica de acordo com características de pétala e sépala.

# %%
# Carregando o dataset
iris = pd.read_csv('iris.data')

# %% [markdown]
# O pandas consegue ler vários tipos de arquivos como excel, txt, html, json e no nosso caso lemos um arquivo txt separado por vírgulas (csv).

# %%
#Usamos o comando shape para verificar o número de linhas e colunas da nossa base de dados.
print(iris.shape)
print('Linhas: ',iris.shape[0])
print('Colunas: ',iris.shape[1])
# Out:
# (149, 5)
# Linhas:  149
# Colunas:  5

# %% [markdown]
# Temos os comandos head(n_primeiras_linhas) e tail(n_ultimas_linhas) que nos mostram respectivamente as primeiras linhas e as útimas do dataframe.

# %%
iris.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
# 5.1            149 non-null float64
# 3.5            149 non-null float64
# 1.4            149 non-null float64
# 0.2            149 non-null float64
# Iris-setosa    149 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris.head(5)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.tail(5)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %% [markdown]
# Renomeado as colunas do nosso dataset

# %%
iris.columns = ['tamanho_sepala','largura_sepala', 'tamaho_petala','largura_petala','Especie']

# %%
iris
# Out:
#      tamanho_sepala  largura_sepala  tamaho_petala  largura_petala  \
# 0               4.9             3.0            1.4             0.2
# 1               4.7             3.2            1.3             0.2
# 2               4.6             3.1            1.5             0.2
# 3               5.0             3.6            1.4             0.2
# 4               5.4             3.9            1.7             0.4
# 5               4.6             3.4            1.4             0.3
# 6               5.0             3.4            1.5             0.2
# 7               4.4             2.9            1.4             0.2
# 8               4.9             3.1            1.5             0.1
# 9               5.4             3.7            1.5             0.2
# 10              4.8             3.4            1.6             0.2
# 11              4.8             3.0            1.4             0.1
# 12              4.3             3.0            1.1             0.1
# 13              5.8             4.0            1.2             0.2
# 14              5.7             4.4            1.5             0.4
# 15              5.4             3.9            1.3             0.4
# 16              5.1             3.5            1.4             0.3
# 17              5.7             3.8            1.7             0.3
# 18              5.1             3.8            1.5             0.3
# 19              5.4             3.4            1.7             0.2
# 20              5.1             3.7            1.5             0.4
# 21              4.6             3.6            1.0             0.2
# 22              5.1             3.3            1.7             0.5
# 23              4.8             3.4            1.9             0.2
# 24              5.0             3.0            1.6             0.2
# 25              5.0             3.4            1.6             0.4
# 26              5.2             3.5            1.5             0.2
# 27              5.2             3.4            1.4             0.2
# 28              4.7             3.2            1.6             0.2
# 29              4.8             3.1            1.6             0.2
# ..              ...             ...            ...             ...
# 119             6.9             3.2            5.7             2.3
# 120             5.6             2.8            4.9             2.0
# 121             7.7             2.8            6.7             2.0
# 122             6.3             2.7            4.9             1.8
# 123             6.7             3.3            5.7             2.1
# 124             7.2             3.2            6.0             1.8
# 125             6.2             2.8            4.8             1.8
# 126             6.1             3.0            4.9             1.8
# 127             6.4             2.8            5.6             2.1
# 128             7.2             3.0            5.8             1.6
# 129             7.4             2.8            6.1             1.9
# 130             7.9             3.8            6.4             2.0
# 131             6.4             2.8            5.6             2.2
# 132             6.3             2.8            5.1             1.5
# 133             6.1             2.6            5.6             1.4
# 134             7.7             3.0            6.1             2.3
# 135             6.3             3.4            5.6             2.4
# 136             6.4             3.1            5.5             1.8
# 137             6.0             3.0            4.8             1.8
# 138             6.9             3.1            5.4             2.1
# 139             6.7             3.1            5.6             2.4
# 140             6.9             3.1            5.1             2.3
# 141             5.8             2.7            5.1             1.9
# 142             6.8             3.2            5.9             2.3
# 143             6.7             3.3            5.7             2.5
# 144             6.7             3.0            5.2             2.3
# 145             6.3             2.5            5.0             1.9
# 146             6.5             3.0            5.2             2.0
# 147             6.2             3.4            5.4             2.3
# 148             5.9             3.0            5.1             1.8
#
#             Especie
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 119  Iris-virginica
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris.values
# Out:
# array([[4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Iris-setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'Iris-setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'Iris-setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'Iris-setosa'],
#        [4.8, 3.4, 1.9, 0.2, 'Iris-setosa'],
#        [5.0, 3.0, 1.6, 0.2, 'Iris-setosa'],
#        [5.0, 3.4, 1.6, 0.4, 'Iris-setosa'],
#        [5.2, 3.5, 1.5, 0.2, 'Iris-setosa'],
#        [5.2, 3.4, 1.4, 0.2, 'Iris-setosa'],
#        [4.7, 3.2, 1.6, 0.2, 'Iris-setosa'],
#        [4.8, 3.1, 1.6, 0.2, 'Iris-setosa'],
#        [5.4, 3.4, 1.5, 0.4, 'Iris-setosa'],
#        [5.2, 4.1, 1.5, 0.1, 'Iris-setosa'],
#        [5.5, 4.2, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [5.0, 3.2, 1.2, 0.2, 'Iris-setosa'],
#        [5.5, 3.5, 1.3, 0.2, 'Iris-setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [4.4, 3.0, 1.3, 0.2, 'Iris-setosa'],
#        [5.1, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.5, 1.3, 0.3, 'Iris-setosa'],
#        [4.5, 2.3, 1.3, 0.3, 'Iris-setosa'],
#        [4.4, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [5.0, 3.5, 1.6, 0.6, 'Iris-setosa'],
#        [5.1, 3.8, 1.9, 0.4, 'Iris-setosa'],
#        [4.8, 3.0, 1.4, 0.3, 'Iris-setosa'],
#        [5.1, 3.8, 1.6, 0.2, 'Iris-setosa'],
#        [4.6, 3.2, 1.4, 0.2, 'Iris-setosa'],
#        [5.3, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.3, 1.4, 0.2, 'Iris-setosa'],
#        [7.0, 3.2, 4.7, 1.4, 'Iris-versicolor'],
#        [6.4, 3.2, 4.5, 1.5, 'Iris-versicolor'],
#        [6.9, 3.1, 4.9, 1.5, 'Iris-versicolor'],
#        [5.5, 2.3, 4.0, 1.3, 'Iris-versicolor'],
#        [6.5, 2.8, 4.6, 1.5, 'Iris-versicolor'],
#        [5.7, 2.8, 4.5, 1.3, 'Iris-versicolor'],
#        [6.3, 3.3, 4.7, 1.6, 'Iris-versicolor'],
#        [4.9, 2.4, 3.3, 1.0, 'Iris-versicolor'],
#        [6.6, 2.9, 4.6, 1.3, 'Iris-versicolor'],
#        [5.2, 2.7, 3.9, 1.4, 'Iris-versicolor'],
#        [5.0, 2.0, 3.5, 1.0, 'Iris-versicolor'],
#        [5.9, 3.0, 4.2, 1.5, 'Iris-versicolor'],
#        [6.0, 2.2, 4.0, 1.0, 'Iris-versicolor'],
#        [6.1, 2.9, 4.7, 1.4, 'Iris-versicolor'],
#        [5.6, 2.9, 3.6, 1.3, 'Iris-versicolor'],
#        [6.7, 3.1, 4.4, 1.4, 'Iris-versicolor'],
#        [5.6, 3.0, 4.5, 1.5, 'Iris-versicolor'],
#        [5.8, 2.7, 4.1, 1.0, 'Iris-versicolor'],
#        [6.2, 2.2, 4.5, 1.5, 'Iris-versicolor'],
#        [5.6, 2.5, 3.9, 1.1, 'Iris-versicolor'],
#        [5.9, 3.2, 4.8, 1.8, 'Iris-versicolor'],
#        [6.1, 2.8, 4.0, 1.3, 'Iris-versicolor'],
#        [6.3, 2.5, 4.9, 1.5, 'Iris-versicolor'],
#        [6.1, 2.8, 4.7, 1.2, 'Iris-versicolor'],
#        [6.4, 2.9, 4.3, 1.3, 'Iris-versicolor'],
#        [6.6, 3.0, 4.4, 1.4, 'Iris-versicolor'],
#        [6.8, 2.8, 4.8, 1.4, 'Iris-versicolor'],
#        [6.7, 3.0, 5.0, 1.7, 'Iris-versicolor'],
#        [6.0, 2.9, 4.5, 1.5, 'Iris-versicolor'],
#        [5.7, 2.6, 3.5, 1.0, 'Iris-versicolor'],
#        [5.5, 2.4, 3.8, 1.1, 'Iris-versicolor'],
#        [5.5, 2.4, 3.7, 1.0, 'Iris-versicolor'],
#        [5.8, 2.7, 3.9, 1.2, 'Iris-versicolor'],
#        [6.0, 2.7, 5.1, 1.6, 'Iris-versicolor'],
#        [5.4, 3.0, 4.5, 1.5, 'Iris-versicolor'],
#        [6.0, 3.4, 4.5, 1.6, 'Iris-versicolor'],
#        [6.7, 3.1, 4.7, 1.5, 'Iris-versicolor'],
#        [6.3, 2.3, 4.4, 1.3, 'Iris-versicolor'],
#        [5.6, 3.0, 4.1, 1.3, 'Iris-versicolor'],
#        [5.5, 2.5, 4.0, 1.3, 'Iris-versicolor'],
#        [5.5, 2.6, 4.4, 1.2, 'Iris-versicolor'],
#        [6.1, 3.0, 4.6, 1.4, 'Iris-versicolor'],
#        [5.8, 2.6, 4.0, 1.2, 'Iris-versicolor'],
#        [5.0, 2.3, 3.3, 1.0, 'Iris-versicolor'],
#        [5.6, 2.7, 4.2, 1.3, 'Iris-versicolor'],
#        [5.7, 3.0, 4.2, 1.2, 'Iris-versicolor'],
#        [5.7, 2.9, 4.2, 1.3, 'Iris-versicolor'],
#        [6.2, 2.9, 4.3, 1.3, 'Iris-versicolor'],
#        [5.1, 2.5, 3.0, 1.1, 'Iris-versicolor'],
#        [5.7, 2.8, 4.1, 1.3, 'Iris-versicolor'],
#        [6.3, 3.3, 6.0, 2.5, 'Iris-virginica'],
#        [5.8, 2.7, 5.1, 1.9, 'Iris-virginica'],
#        [7.1, 3.0, 5.9, 2.1, 'Iris-virginica'],
#        [6.3, 2.9, 5.6, 1.8, 'Iris-virginica'],
#        [6.5, 3.0, 5.8, 2.2, 'Iris-virginica'],
#        [7.6, 3.0, 6.6, 2.1, 'Iris-virginica'],
#        [4.9, 2.5, 4.5, 1.7, 'Iris-virginica'],
#        [7.3, 2.9, 6.3, 1.8, 'Iris-virginica'],
#        [6.7, 2.5, 5.8, 1.8, 'Iris-virginica'],
#        [7.2, 3.6, 6.1, 2.5, 'Iris-virginica'],
#        [6.5, 3.2, 5.1, 2.0, 'Iris-virginica'],
#        [6.4, 2.7, 5.3, 1.9, 'Iris-virginica'],
#        [6.8, 3.0, 5.5, 2.1, 'Iris-virginica'],
#        [5.7, 2.5, 5.0, 2.0, 'Iris-virginica'],
#        [5.8, 2.8, 5.1, 2.4, 'Iris-virginica'],
#        [6.4, 3.2, 5.3, 2.3, 'Iris-virginica'],
#        [6.5, 3.0, 5.5, 1.8, 'Iris-virginica'],
#        [7.7, 3.8, 6.7, 2.2, 'Iris-virginica'],
#        [7.7, 2.6, 6.9, 2.3, 'Iris-virginica'],
#        [6.0, 2.2, 5.0, 1.5, 'Iris-virginica'],
#        [6.9, 3.2, 5.7, 2.3, 'Iris-virginica'],
#        [5.6, 2.8, 4.9, 2.0, 'Iris-virginica'],
#        [7.7, 2.8, 6.7, 2.0, 'Iris-virginica'],
#        [6.3, 2.7, 4.9, 1.8, 'Iris-virginica'],
#        [6.7, 3.3, 5.7, 2.1, 'Iris-virginica'],
#        [7.2, 3.2, 6.0, 1.8, 'Iris-virginica'],
#        [6.2, 2.8, 4.8, 1.8, 'Iris-virginica'],
#        [6.1, 3.0, 4.9, 1.8, 'Iris-virginica'],
#        [6.4, 2.8, 5.6, 2.1, 'Iris-virginica'],
#        [7.2, 3.0, 5.8, 1.6, 'Iris-virginica'],
#        [7.4, 2.8, 6.1, 1.9, 'Iris-virginica'],
#        [7.9, 3.8, 6.4, 2.0, 'Iris-virginica'],
#        [6.4, 2.8, 5.6, 2.2, 'Iris-virginica'],
#        [6.3, 2.8, 5.1, 1.5, 'Iris-virginica'],
#        [6.1, 2.6, 5.6, 1.4, 'Iris-virginica'],
#        [7.7, 3.0, 6.1, 2.3, 'Iris-virginica'],
#        [6.3, 3.4, 5.6, 2.4, 'Iris-virginica'],
#        [6.4, 3.1, 5.5, 1.8, 'Iris-virginica'],
#        [6.0, 3.0, 4.8, 1.8, 'Iris-virginica'],
#        [6.9, 3.1, 5.4, 2.1, 'Iris-virginica'],
#        [6.7, 3.1, 5.6, 2.4, 'Iris-virginica'],
#        [6.9, 3.1, 5.1, 2.3, 'Iris-virginica'],
#        [5.8, 2.7, 5.1, 1.9, 'Iris-virginica'],
#        [6.8, 3.2, 5.9, 2.3, 'Iris-virginica'],
#        [6.7, 3.3, 5.7, 2.5, 'Iris-virginica'],
#        [6.7, 3.0, 5.2, 2.3, 'Iris-virginica'],
#        [6.3, 2.5, 5.0, 1.9, 'Iris-virginica'],
#        [6.5, 3.0, 5.2, 2.0, 'Iris-virginica'],
#        [6.2, 3.4, 5.4, 2.3, 'Iris-virginica'],
#        [5.9, 3.0, 5.1, 1.8, 'Iris-virginica']], dtype=object)

# %%
# Retorna o dataset transposto
iris.T
# Out:
#                         0            1            2            3    \
# tamanho_sepala          4.9          4.7          4.6            5
# largura_sepala            3          3.2          3.1          3.6
# tamaho_petala           1.4          1.3          1.5          1.4
# largura_petala          0.2          0.2          0.2          0.2
# Especie         Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                         4            5            6            7    \
# tamanho_sepala          5.4          4.6            5          4.4
# largura_sepala          3.9          3.4          3.4          2.9
# tamaho_petala           1.7          1.4          1.5          1.4
# largura_petala          0.4          0.3          0.2          0.2
# Especie         Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                         8            9         ...                   139  \
# tamanho_sepala          4.9          5.4       ...                   6.7
# largura_sepala          3.1          3.7       ...                   3.1
# tamaho_petala           1.5          1.5       ...                   5.6
# largura_petala          0.1          0.2       ...                   2.4
# Especie         Iris-setosa  Iris-setosa       ...        Iris-virginica
#
#                            140             141             142  \
# tamanho_sepala             6.9             5.8             6.8
# largura_sepala             3.1             2.7             3.2
# tamaho_petala              5.1             5.1             5.9
# largura_petala             2.3             1.9             2.3
# Especie         Iris-virginica  Iris-virginica  Iris-virginica
#
#                            143             144             145  \
# tamanho_sepala             6.7             6.7             6.3
# largura_sepala             3.3               3             2.5
# tamaho_petala              5.7             5.2               5
# largura_petala             2.5             2.3             1.9
# Especie         Iris-virginica  Iris-virginica  Iris-virginica
#
#                            146             147             148
# tamanho_sepala             6.5             6.2             5.9
# largura_sepala               3             3.4               3
# tamaho_petala              5.2             5.4             5.1
# largura_petala               2             2.3             1.8
# Especie         Iris-virginica  Iris-virginica  Iris-virginica
#
# [5 rows x 149 columns]

# %%
# Ordenando o dataset
iris.sort_index(axis=1,ascending=False)
# Out:
#      tamanho_sepala  tamaho_petala  largura_sepala  largura_petala  \
# 0               4.9            1.4             3.0             0.2
# 1               4.7            1.3             3.2             0.2
# 2               4.6            1.5             3.1             0.2
# 3               5.0            1.4             3.6             0.2
# 4               5.4            1.7             3.9             0.4
# 5               4.6            1.4             3.4             0.3
# 6               5.0            1.5             3.4             0.2
# 7               4.4            1.4             2.9             0.2
# 8               4.9            1.5             3.1             0.1
# 9               5.4            1.5             3.7             0.2
# 10              4.8            1.6             3.4             0.2
# 11              4.8            1.4             3.0             0.1
# 12              4.3            1.1             3.0             0.1
# 13              5.8            1.2             4.0             0.2
# 14              5.7            1.5             4.4             0.4
# 15              5.4            1.3             3.9             0.4
# 16              5.1            1.4             3.5             0.3
# 17              5.7            1.7             3.8             0.3
# 18              5.1            1.5             3.8             0.3
# 19              5.4            1.7             3.4             0.2
# 20              5.1            1.5             3.7             0.4
# 21              4.6            1.0             3.6             0.2
# 22              5.1            1.7             3.3             0.5
# 23              4.8            1.9             3.4             0.2
# 24              5.0            1.6             3.0             0.2
# 25              5.0            1.6             3.4             0.4
# 26              5.2            1.5             3.5             0.2
# 27              5.2            1.4             3.4             0.2
# 28              4.7            1.6             3.2             0.2
# 29              4.8            1.6             3.1             0.2
# ..              ...            ...             ...             ...
# 119             6.9            5.7             3.2             2.3
# 120             5.6            4.9             2.8             2.0
# 121             7.7            6.7             2.8             2.0
# 122             6.3            4.9             2.7             1.8
# 123             6.7            5.7             3.3             2.1
# 124             7.2            6.0             3.2             1.8
# 125             6.2            4.8             2.8             1.8
# 126             6.1            4.9             3.0             1.8
# 127             6.4            5.6             2.8             2.1
# 128             7.2            5.8             3.0             1.6
# 129             7.4            6.1             2.8             1.9
# 130             7.9            6.4             3.8             2.0
# 131             6.4            5.6             2.8             2.2
# 132             6.3            5.1             2.8             1.5
# 133             6.1            5.6             2.6             1.4
# 134             7.7            6.1             3.0             2.3
# 135             6.3            5.6             3.4             2.4
# 136             6.4            5.5             3.1             1.8
# 137             6.0            4.8             3.0             1.8
# 138             6.9            5.4             3.1             2.1
# 139             6.7            5.6             3.1             2.4
# 140             6.9            5.1             3.1             2.3
# 141             5.8            5.1             2.7             1.9
# 142             6.8            5.9             3.2             2.3
# 143             6.7            5.7             3.3             2.5
# 144             6.7            5.2             3.0             2.3
# 145             6.3            5.0             2.5             1.9
# 146             6.5            5.2             3.0             2.0
# 147             6.2            5.4             3.4             2.3
# 148             5.9            5.1             3.0             1.8
#
#             Especie
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 119  Iris-virginica
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris.sort_values(by='tamanho_sepala')
# Out:
#      tamanho_sepala  largura_sepala  tamaho_petala  largura_petala  \
# 12              4.3             3.0            1.1             0.1
# 41              4.4             3.2            1.3             0.2
# 37              4.4             3.0            1.3             0.2
# 7               4.4             2.9            1.4             0.2
# 40              4.5             2.3            1.3             0.3
# 46              4.6             3.2            1.4             0.2
# 2               4.6             3.1            1.5             0.2
# 5               4.6             3.4            1.4             0.3
# 21              4.6             3.6            1.0             0.2
# 28              4.7             3.2            1.6             0.2
# 1               4.7             3.2            1.3             0.2
# 10              4.8             3.4            1.6             0.2
# 11              4.8             3.0            1.4             0.1
# 29              4.8             3.1            1.6             0.2
# 44              4.8             3.0            1.4             0.3
# 23              4.8             3.4            1.9             0.2
# 33              4.9             3.1            1.5             0.1
# 36              4.9             3.1            1.5             0.1
# 0               4.9             3.0            1.4             0.2
# 105             4.9             2.5            4.5             1.7
# 8               4.9             3.1            1.5             0.1
# 56              4.9             2.4            3.3             1.0
# 34              5.0             3.2            1.2             0.2
# 59              5.0             2.0            3.5             1.0
# 92              5.0             2.3            3.3             1.0
# 42              5.0             3.5            1.6             0.6
# 48              5.0             3.3            1.4             0.2
# 39              5.0             3.5            1.3             0.3
# 25              5.0             3.4            1.6             0.4
# 6               5.0             3.4            1.5             0.2
# ..              ...             ...            ...             ...
# 74              6.6             3.0            4.4             1.4
# 57              6.6             2.9            4.6             1.3
# 76              6.7             3.0            5.0             1.7
# 139             6.7             3.1            5.6             2.4
# 64              6.7             3.1            4.4             1.4
# 144             6.7             3.0            5.2             2.3
# 107             6.7             2.5            5.8             1.8
# 143             6.7             3.3            5.7             2.5
# 85              6.7             3.1            4.7             1.5
# 123             6.7             3.3            5.7             2.1
# 75              6.8             2.8            4.8             1.4
# 142             6.8             3.2            5.9             2.3
# 111             6.8             3.0            5.5             2.1
# 51              6.9             3.1            4.9             1.5
# 138             6.9             3.1            5.4             2.1
# 140             6.9             3.1            5.1             2.3
# 119             6.9             3.2            5.7             2.3
# 49              7.0             3.2            4.7             1.4
# 101             7.1             3.0            5.9             2.1
# 128             7.2             3.0            5.8             1.6
# 108             7.2             3.6            6.1             2.5
# 124             7.2             3.2            6.0             1.8
# 106             7.3             2.9            6.3             1.8
# 129             7.4             2.8            6.1             1.9
# 104             7.6             3.0            6.6             2.1
# 117             7.7             2.6            6.9             2.3
# 116             7.7             3.8            6.7             2.2
# 121             7.7             2.8            6.7             2.0
# 134             7.7             3.0            6.1             2.3
# 130             7.9             3.8            6.4             2.0
#
#              Especie
# 12       Iris-setosa
# 41       Iris-setosa
# 37       Iris-setosa
# 7        Iris-setosa
# 40       Iris-setosa
# 46       Iris-setosa
# 2        Iris-setosa
# 5        Iris-setosa
# 21       Iris-setosa
# 28       Iris-setosa
# 1        Iris-setosa
# 10       Iris-setosa
# 11       Iris-setosa
# 29       Iris-setosa
# 44       Iris-setosa
# 23       Iris-setosa
# 33       Iris-setosa
# 36       Iris-setosa
# 0        Iris-setosa
# 105   Iris-virginica
# 8        Iris-setosa
# 56   Iris-versicolor
# 34       Iris-setosa
# 59   Iris-versicolor
# 92   Iris-versicolor
# 42       Iris-setosa
# 48       Iris-setosa
# 39       Iris-setosa
# 25       Iris-setosa
# 6        Iris-setosa
# ..               ...
# 74   Iris-versicolor
# 57   Iris-versicolor
# 76   Iris-versicolor
# 139   Iris-virginica
# 64   Iris-versicolor
# 144   Iris-virginica
# 107   Iris-virginica
# 143   Iris-virginica
# 85   Iris-versicolor
# 123   Iris-virginica
# 75   Iris-versicolor
# 142   Iris-virginica
# 111   Iris-virginica
# 51   Iris-versicolor
# 138   Iris-virginica
# 140   Iris-virginica
# 119   Iris-virginica
# 49   Iris-versicolor
# 101   Iris-virginica
# 128   Iris-virginica
# 108   Iris-virginica
# 124   Iris-virginica
# 106   Iris-virginica
# 129   Iris-virginica
# 104   Iris-virginica
# 117   Iris-virginica
# 116   Iris-virginica
# 121   Iris-virginica
# 134   Iris-virginica
# 130   Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# #### Obtendo campos

# %%
iris['tamanho_sepala']
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
# 5      4.6
# 6      5.0
# 7      4.4
# 8      4.9
# 9      5.4
# 10     4.8
# 11     4.8
# 12     4.3
# 13     5.8
# 14     5.7
# 15     5.4
# 16     5.1
# 17     5.7
# 18     5.1
# 19     5.4
# 20     5.1
# 21     4.6
# 22     5.1
# 23     4.8
# 24     5.0
# 25     5.0
# 26     5.2
# 27     5.2
# 28     4.7
# 29     4.8
#       ...
# 119    6.9
# 120    5.6
# 121    7.7
# 122    6.3
# 123    6.7
# 124    7.2
# 125    6.2
# 126    6.1
# 127    6.4
# 128    7.2
# 129    7.4
# 130    7.9
# 131    6.4
# 132    6.3
# 133    6.1
# 134    7.7
# 135    6.3
# 136    6.4
# 137    6.0
# 138    6.9
# 139    6.7
# 140    6.9
# 141    5.8
# 142    6.8
# 143    6.7
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: tamanho_sepala, Length: 149, dtype: float64

# %%
iris[0:3]
# Out:
#    tamanho_sepala  largura_sepala  tamaho_petala  largura_petala      Especie
# 0             4.9             3.0            1.4             0.2  Iris-setosa
# 1             4.7             3.2            1.3             0.2  Iris-setosa
# 2             4.6             3.1            1.5             0.2  Iris-setosa

# %%
# obter pela linha e não pela coluna
iris.loc[0]
# Out:
# tamanho_sepala            4.9
# largura_sepala              3
# tamaho_petala             1.4
# largura_petala            0.2
# Especie           Iris-setosa
# Name: 0, dtype: object

# %%
iris.loc[:,['tamanho_sepala','largura_sepala']]
# Out:
#      tamanho_sepala  largura_sepala
# 0               4.9             3.0
# 1               4.7             3.2
# 2               4.6             3.1
# 3               5.0             3.6
# 4               5.4             3.9
# 5               4.6             3.4
# 6               5.0             3.4
# 7               4.4             2.9
# 8               4.9             3.1
# 9               5.4             3.7
# 10              4.8             3.4
# 11              4.8             3.0
# 12              4.3             3.0
# 13              5.8             4.0
# 14              5.7             4.4
# 15              5.4             3.9
# 16              5.1             3.5
# 17              5.7             3.8
# 18              5.1             3.8
# 19              5.4             3.4
# 20              5.1             3.7
# 21              4.6             3.6
# 22              5.1             3.3
# 23              4.8             3.4
# 24              5.0             3.0
# 25              5.0             3.4
# 26              5.2             3.5
# 27              5.2             3.4
# 28              4.7             3.2
# 29              4.8             3.1
# ..              ...             ...
# 119             6.9             3.2
# 120             5.6             2.8
# 121             7.7             2.8
# 122             6.3             2.7
# 123             6.7             3.3
# 124             7.2             3.2
# 125             6.2             2.8
# 126             6.1             3.0
# 127             6.4             2.8
# 128             7.2             3.0
# 129             7.4             2.8
# 130             7.9             3.8
# 131             6.4             2.8
# 132             6.3             2.8
# 133             6.1             2.6
# 134             7.7             3.0
# 135             6.3             3.4
# 136             6.4             3.1
# 137             6.0             3.0
# 138             6.9             3.1
# 139             6.7             3.1
# 140             6.9             3.1
# 141             5.8             2.7
# 142             6.8             3.2
# 143             6.7             3.3
# 144             6.7             3.0
# 145             6.3             2.5
# 146             6.5             3.0
# 147             6.2             3.4
# 148             5.9             3.0
#
# [149 rows x 2 columns]

# %%
# Obtendo pela posição
iris.iloc[3][3]
# Out:
# 0.20000000000000001

# %%
iris.iloc[3:5, 0:2]
# Out:
#    tamanho_sepala  largura_sepala
# 3             5.0             3.6
# 4             5.4             3.9

# %% [markdown]
# ### Operações

# %%
#Média
iris.mean()
# Out:
# tamanho_sepala    5.848322
# largura_sepala    3.051007
# tamaho_petala     3.774497
# largura_petala    1.205369
# dtype: float64

# %%
correlacao = iris.corr()
correlacao
# Out:
#                 tamanho_sepala  largura_sepala  tamaho_petala  largura_petala
# tamanho_sepala        1.000000       -0.103784       0.871283        0.816971
# largura_sepala       -0.103784        1.000000      -0.415218       -0.350733
# tamaho_petala         0.871283       -0.415218       1.000000        0.962314
# largura_petala        0.816971       -0.350733       0.962314        1.000000

# %% [markdown]
# ### Visualização

# %%
correlacao.hist(figsize=(20,20));

# %%
pd.tools.plotting.scatter_matrix(correlacao, figsize=(9,9));
# Out:
# /home/computer/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
